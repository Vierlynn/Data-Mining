# %% [markdown]
# # <center> Data Mining: Agglomerative Clustering </center>
#
#
# Name: Nanda Hakiki
#
# SID: 1301160443
#
#
# reference: https://www.youtube.com/watch?v=v7oLMvcxgFY

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## Defining datasets

# %%
x, y = make_blobs(
    n_samples=250, n_features=2,
    centers=3, cluster_std=1.5,
    shuffle=True, random_state=50
)

# %% [markdown]
# ## Hierarchial Agglomerative Clustering

# %%
dendrogram = sch.dendrogram(sch.linkage(x, method='ward'))

# %%
plt.scatter(x[:,0], x[:,1])

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage='ward')

# %%
y_hc = hc.fit_predict(x)

# %% [markdown]
# ## defining plot for clusters

# %%
#clusters
plt.scatter(
    x[y_hc == 0, 0], x[y_hc == 0, 1],
    s=25, c='red'
)
plt.scatter(
    x[y_hc == 1, 0], x[y_hc == 1, 1],
    s=25, c='blue'
)
plt.scatter(
    x[y_hc == 2, 0], x[y_hc == 2, 1],
    s=25, c='green'
)

plt.show()
